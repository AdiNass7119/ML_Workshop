# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in C:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in C:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.4.0 in C:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages (from scikit-learn) (2.24.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in C:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

# %%
import sklearn

# %%
data = pd.DataFrame({'Price_USA': [80,50,140,25],'Price_INR': [5000,7000,12000,3000]})
data
# Out:
#    Price_USA  Price_INR
# 0         80       5000
# 1         50       7000
# 2        140      12000
# 3         25       3000

# %%
data['Price_USA_minmax'] = (data['Price_USA'] - data['Price_USA'].min())/(data['Price_USA'].max() - data['Price_USA'].min())
data
# Out:
#    Price_USA  Price_INR  Price_USA_minmax
# 0         80       5000          0.478261
# 1         50       7000          0.217391
# 2        140      12000          1.000000
# 3         25       3000          0.000000

# %%
data['Price_INR_minmax'] = (data['Price_INR'] - data['Price_INR'].min())/(data['Price_INR'].max() - data['Price_INR'].min())
data
# Out:
#    Price_USA  Price_INR  Price_USA_minmax  Price_INR_minmax
# 0         80       5000          0.478261          0.222222
# 1         50       7000          0.217391          0.444444
# 2        140      12000          1.000000          1.000000
# 3         25       3000          0.000000          0.000000

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler

# %%
min_max=MinMaxScaler()

# %%
#We need to use fit_transform()
data['Price_USA_minsk'] = min_max.fit_transform(data[['Price_USA']])
data
# Out:
#    Price_USA  Price_INR  Price_USA_minmax  Price_INR_minmax  Price_USA_minsk
# 0         80       5000          0.478261          0.222222         0.478261
# 1         50       7000          0.217391          0.444444         0.217391
# 2        140      12000          1.000000          1.000000         1.000000
# 3         25       3000          0.000000          0.000000         0.000000

# %%
data['Price_INR_minsk'] = min_max.fit_transform(data[['Price_INR']])
data
# Out:
#    Price_USA  Price_INR  Price_USA_minmax  Price_INR_minmax  Price_USA_minsk  \
# 0         80       5000          0.478261          0.222222         0.478261
# 1         50       7000          0.217391          0.444444         0.217391
# 2        140      12000          1.000000          1.000000         1.000000
# 3         25       3000          0.000000          0.000000         0.000000
#
#    Price_INR_minsk
# 0         0.222222
# 1         0.444444
# 2         1.000000
# 3         0.000000

# %%
data['Price_USA_std'] = (data['Price_USA'] - data['Price_USA'].mean())/(data['Price_USA'].std())
data
# Out:
#    Price_USA  Price_INR  Price_USA_minmax  Price_INR_minmax  Price_USA_minsk  \
# 0         80       5000          0.478261          0.222222         0.478261
# 1         50       7000          0.217391          0.444444         0.217391
# 2        140      12000          1.000000          1.000000         1.000000
# 3         25       3000          0.000000          0.000000         0.000000
#
#    Price_INR_minsk  Price_USA_std
# 0         0.222222       0.126108
# 1         0.444444      -0.479212
# 2         1.000000       1.336748
# 3         0.000000      -0.983645

# %%
data['Price_INR_std'] = (data['Price_INR'] - data['Price_INR'].mean())/(data['Price_INR'].std())
data
# Out:
#    Price_USA  Price_INR  Price_USA_minmax  Price_INR_minmax  Price_USA_minsk  \
# 0         80       5000          0.478261          0.222222         0.478261
# 1         50       7000          0.217391          0.444444         0.217391
# 2        140      12000          1.000000          1.000000         1.000000
# 3         25       3000          0.000000          0.000000         0.000000
#
#    Price_INR_minsk  Price_USA_std  Price_INR_std
# 0         0.222222       0.126108      -0.453108
# 1         0.444444      -0.479212       0.064730
# 2         1.000000       1.336748       1.359325
# 3         0.000000      -0.983645      -0.970947

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
data['Price_USA_Scaler'] = scaler.fit_transform(data[['Price_USA']])
data
# Out:
#    Price_USA  Price_INR  Price_USA_minmax  Price_INR_minmax  Price_USA_minsk  \
# 0         80       5000          0.478261          0.222222         0.478261
# 1         50       7000          0.217391          0.444444         0.217391
# 2        140      12000          1.000000          1.000000         1.000000
# 3         25       3000          0.000000          0.000000         0.000000
#
#    Price_INR_minsk  Price_USA_std  Price_INR_std  Price_USA_Scaler
# 0         0.222222       0.126108      -0.453108          0.145617
# 1         0.444444      -0.479212       0.064730         -0.553346
# 2         1.000000       1.336748       1.359325          1.543544
# 3         0.000000      -0.983645      -0.970947         -1.135815

# %%
from sklearn.preprocessing import RobustScaler

# %%
robust = RobustScaler()

# %%
data['Price_USA_robust'] = robust.fit_transform(data[['Price_USA']])
data
data['Price_INR_robust'] = robust.fit_transform(data[['Price_INR']])
data
# Out:
#    Price_USA  Price_INR  Price_USA_minmax  Price_INR_minmax  Price_USA_minsk  \
# 0         80       5000          0.478261          0.222222         0.478261
# 1         50       7000          0.217391          0.444444         0.217391
# 2        140      12000          1.000000          1.000000         1.000000
# 3         25       3000          0.000000          0.000000         0.000000
#
#    Price_INR_minsk  Price_USA_std  Price_INR_std  Price_USA_Scaler  \
# 0         0.222222       0.126108      -0.453108          0.145617
# 1         0.444444      -0.479212       0.064730         -0.553346
# 2         1.000000       1.336748       1.359325          1.543544
# 3         0.000000      -0.983645      -0.970947         -1.135815
#
#    Price_USA_robust  Price_INR_robust
# 0          0.292683         -0.266667
# 1         -0.292683          0.266667
# 2          1.463415          1.600000
# 3         -0.780488         -0.800000

# %%
pip install ucimlrepo
# Out:
# Requirement already satisfied: ucimlrepo in C:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages (0.0.7)
# Requirement already satisfied: pandas>=1.0.0 in C:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages (from ucimlrepo) (2.2.2)
# Requirement already satisfied: certifi>=2020.12.5 in C:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages (from ucimlrepo) (2026.7.22)
# Requirement already satisfied: numpy>=1.23.2 in C:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas>=1.0.0->ucimlrepo) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2026.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2026.3)
# Requirement already satisfied: six>=1.5 in C:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from ucimlrepo import fetch_ucirepo
from sklearn.linear_model import LinearRegression
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import OneHotEncoder,PolynomialFeatures
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
sns.set_style(style='whitegrid')

# %%
#STEP-02: Loading And Cleaning the Data (autompg dataset)
data = fetch_ucirepo(id = 9)
data
x = data.data.features.copy()  #it returs all nummerical features
y = data.data.targets['mpg']
x
# Out:
#      displacement  cylinders  horsepower  weight  acceleration  model_year  \
# 0           307.0          8       130.0    3504          12.0          70
# 1           350.0          8       165.0    3693          11.5          70
# 2           318.0          8       150.0    3436          11.0          70
# 3           304.0          8       150.0    3433          12.0          70
# 4           302.0          8       140.0    3449          10.5          70
# ..            ...        ...         ...     ...           ...         ...
# 393         140.0          4        86.0    2790          15.6          82
# 394          97.0          4        52.0    2130          24.6          82
# 395         135.0          4        84.0    2295          11.6          82
# 396         120.0          4        79.0    2625          18.6          82
# 397         119.0          4        82.0    2720          19.4          82
#
#      origin
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ..      ...
# 393       1
# 394       2
# 395       1
# 396       1
# 397       1
#
# [398 rows x 7 columns]

# %%
x.describe()
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   displacement  398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   horsepower    392 non-null    float64
#  3   weight        398 non-null    int64
#  4   acceleration  398 non-null    float64
#  5   model_year    398 non-null    int64
#  6   origin        398 non-null    int64
# dtypes: float64(3), int64(4)
# memory usage: 21.9 KB

# %%
x['origin'].unique();
x['horsepower'].unique()
# Out:
# array([130., 165., 150., 140., 198., 220., 215., 225., 190., 170., 160.,
#         95.,  97.,  85.,  88.,  46.,  87.,  90., 113., 200., 210., 193.,
#         nan, 100., 105., 175., 153., 180., 110.,  72.,  86.,  70.,  76.,
#         65.,  69.,  60.,  80.,  54., 208., 155., 112.,  92., 145., 137.,
#        158., 167.,  94., 107., 230.,  49.,  75.,  91., 122.,  67.,  83.,
#         78.,  52.,  61.,  93., 148., 129.,  96.,  71.,  98., 115.,  53.,
#         81.,  79., 120., 152., 102., 108.,  68.,  58., 149.,  89.,  63.,
#         48.,  66., 139., 103., 125., 133., 138., 135., 142.,  77.,  62.,
#        132.,  84.,  64.,  74., 116.,  82.])

# %%
#first we will transform the horse power and origin coloumns
x['horsepower'] = pd.to_numeric(x['horsepower'],errors = 'coerce')
x['origin'] = x['origin'].astype(str)

# %%
x.info();
numerical_features = ['cylinders','displacement','horsepower','weight',
                      'accleration','model_year']
categorical_features = ['origin']
x = x[numerical_features+categorical_features]
x.info()
#x.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   displacement  398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   horsepower    392 non-null    float64
#  3   weight        398 non-null    int64
#  4   acceleration  398 non-null    float64
#  5   model_year    398 non-null    int64
#  6   origin        398 non-null    object
# dtypes: float64(3), int64(3), object(1)
# memory usage: 21.9+ KB
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 5
#       1 x.info();
#       2 numerical_features = ['cylinders','displacement','horsepower','weight',
#       3                       'accleration','model_year']
#       4 categorical_features = ['origin']
# ----> 5 x = x[numerical_features+categorical_features]
#       6 x.info()
#       7 #x.isnull().sum()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4104                 indexer = [indexer]
#    4105         else:
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#    4111         if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['accleration'] not in index"

# %%
x.shape
# Out:
# (398, 7)

# %%
#Step-03:Quick Exploratory Data Analysis
df = x.copy()
df['mpg'] = y
#here we are mapping

# %%
 #we are gonna use sunplots() concept to divide plot into multiple plots
fig,axes = plt.subplots(1,3,figsize = (16,4))
#plot graphs as per axes
sns.histplot(df['mpg'],kde = False,ax = axes[0],color = 'purple')
axes[0].set_title("MPG Disribution")
sns.scatterplot(x = df['weight'],y = df['mpg'],ax = axes[1],color = 'orange')
axes[1].set_title("Weight VS MPG Distribution")
sns.scatterplot(x = df['horsepower'],y = df['mpg'],ax = axes[2],color = 'green')
axes[2].set_title("HorsePower VS MPG Distribution")
# Out:
# Text(0.5, 1.0, 'HorsePower VS MPG Distribution')

# %%
plt.figure(figsize=(16,4))
sns.heatmap(df.select_dtypes(include=np.number).corr(),
            annot=True,
            cmap='coolwarm',
            center=0)
plt.title("CORRELATION MATRIX")
plt.tight_layout()
plt.show()

# %%
print(x)
print(y)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
print("/n Train test Split")
print("Training Data :",len(x_train))
print("Testing Data :",len(x_test))
# Out:
#      displacement  cylinders  horsepower  weight  acceleration  model_year  \
# 0           307.0          8       130.0    3504          12.0          70
# 1           350.0          8       165.0    3693          11.5          70
# 2           318.0          8       150.0    3436          11.0          70
# 3           304.0          8       150.0    3433          12.0          70
# 4           302.0          8       140.0    3449          10.5          70
# ..            ...        ...         ...     ...           ...         ...
# 393         140.0          4        86.0    2790          15.6          82
# 394          97.0          4        52.0    2130          24.6          82
# 395         135.0          4        84.0    2295          11.6          82
# 396         120.0          4        79.0    2625          18.6          82
# 397         119.0          4        82.0    2720          19.4          82
#
#     origin
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# ..     ...
# 393      1
# 394      2
# 395      1
# 396      1
# 397      1
#
# [398 rows x 7 columns]
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64
# /n Train test Split
# Training Data : 318
# Testing Data : 80

# %%
def evaluate(model_name,actual,predicted):
    mse=mean_squared_error(actual,predicted)
    return {'Mode Name':model_name,
            'MAE':mean_absolute_error,
            'MSE':mse,
            'RSME':np.sqrt(mse),
            'R2_SCORE':r2_score(actual,predicted)}
results=[]

# %%
base_line_predictions = np.full(len(y_test),y_train.mean())
#base_line_predictions

#in above case we are keeping a baseline predictions
results.append(evaluate("Mean Baseline",y_test,base_line_predictions))
results
# Out:
# [{'Mode Name': 'Mean Baseline',
#   'MAE': <function sklearn.metrics._regression.mean_absolute_error(y_true, y_pred, *, sample_weight=None, multioutput='uniform_average')>,
#   'MSE': 53.98329798069697,
#   'RSME': 7.347332711991268,
#   'R2_SCORE': -0.00403326341807686},
#  {'Mode Name': 'Mean Baseline',
#   'MAE': <function sklearn.metrics._regression.mean_absolute_error(y_true, y_pred, *, sample_weight=None, multioutput='uniform_average')>,
#   'MSE': 53.98329798069697,
#   'RSME': 7.347332711991268,
#   'R2_SCORE': -0.00403326341807686}]

# %%
simple_model = LinearRegression()
#we fit the data to the model
simple_model.fit(x_train[['cylinders']],y_train)
simple_model_predictions = simple_model.predict(x_test[['cylinders']])
print(simple_model_predictions)
results.append(evaluate("Simple Linear Regression:Cylinders",y_test,
                        simple_model_predictions))
print(len(results))
print(results)
# Out:
# [28.79679762 28.79679762 21.54413106 14.2914645  14.2914645  28.79679762
#  28.79679762 14.2914645  14.2914645  21.54413106 14.2914645  28.79679762
#  28.79679762 14.2914645  28.79679762 14.2914645  28.79679762 21.54413106
#  14.2914645  28.79679762 28.79679762 21.54413106 21.54413106 28.79679762
#  14.2914645  28.79679762 28.79679762 28.79679762 21.54413106 14.2914645
#  28.79679762 28.79679762 14.2914645  28.79679762 28.79679762 14.2914645
#  21.54413106 14.2914645  14.2914645  28.79679762 21.54413106 28.79679762
#  28.79679762 14.2914645  28.79679762 28.79679762 28.79679762 28.79679762
#  28.79679762 28.79679762 28.79679762 28.79679762 28.79679762 14.2914645
#  21.54413106 14.2914645  14.2914645  28.79679762 28.79679762 21.54413106
#  14.2914645  28.79679762 28.79679762 28.79679762 21.54413106 28.79679762
#  28.79679762 28.79679762 28.79679762 14.2914645  28.79679762 14.2914645
#  14.2914645  21.54413106 21.54413106 14.2914645  21.54413106 28.79679762
#  28.79679762 14.2914645 ]
# 3
# [{'Mode Name': 'Mean Baseline', 'MAE': <function mean_absolute_error at 0x000002378E522340>, 'MSE': 53.98329798069697, 'RSME': 7.347332711991268, 'R2_SCORE': -0.00403326341807686}, {'Mode Name': 'Mean Baseline', 'MAE': <function mean_absolute_error at 0x000002378E522340>, 'MSE': 53.98329798069697, 'RSME': 7.347332711991268, 'R2_SCORE': -0.00403326341807686}, {'Mode Name': 'Simple Linear Regression:Cylinders', 'MAE': <function mean_absolute_error at 0x000002378E522340>, 'MSE': 19.664864157034096, 'RSME': 4.434508333179012, 'R2_SCORE': 0.6342539549673287}]

# %%
results
# Out:
# [{'Mode Name': 'Mean Baseline',
#   'MAE': <function sklearn.metrics._regression.mean_absolute_error(y_true, y_pred, *, sample_weight=None, multioutput='uniform_average')>,
#   'MSE': 53.98329798069697,
#   'RSME': 7.347332711991268,
#   'R2_SCORE': -0.00403326341807686},
#  {'Mode Name': 'Mean Baseline',
#   'MAE': <function sklearn.metrics._regression.mean_absolute_error(y_true, y_pred, *, sample_weight=None, multioutput='uniform_average')>,
#   'MSE': 53.98329798069697,
#   'RSME': 7.347332711991268,
#   'R2_SCORE': -0.00403326341807686},
#  {'Mode Name': 'Simple Linear Regression:Cylinders',
#   'MAE': <function sklearn.metrics._regression.mean_absolute_error(y_true, y_pred, *, sample_weight=None, multioutput='uniform_average')>,
#   'MSE': 19.664864157034096,
#   'RSME': 4.434508333179012,
#   'R2_SCORE': 0.6342539549673287}]

# %%
#We will Check intercept value
print(f'Simple Linear Regression Equation')
print(f"Predicted MPG = {simple_model.intercept_}+({simple_model.coef_[0]})*weight")
# Out:
# Simple Linear Regression Equation
# Predicted MPG = 43.30213072996193+(-3.626333278591717)*weight
